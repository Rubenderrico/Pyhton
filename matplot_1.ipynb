# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
x = np.linspace(0,5,11)
y = x**2
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
plt.plot(x,y,'green')
plt.xlabel('Asse Ordinate')
plt.ylabel('Asse Coordinate')
plt.title('Grafico 1')

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.sublot(1,2,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-f9458b62673c> in <module>()
# ----> 1 plt.sublot(1,2,1)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'sublot'

# %%
plt.Subplot(1,2,1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-bffa01e6dda4> in <module>()
# ----> 1 plt.Subplot(1,2,1)
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      70                 # num - 1 for converting from MATLAB to python indexing
#      71         else:
# ---> 72             raise ValueError('Illegal argument(s) to subplot: %s' % (args,))
#      73
#      74         self.update_params()
#
# ValueError: Illegal argument(s) to subplot: (2, 1)

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(y,x,'g')

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(y,x,'g')

# %%
plt.subplot(2,2,2)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(y,x,'g')

# %%
plt.subplot(1,3,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(y,x,'g')
